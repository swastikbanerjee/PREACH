# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikbanerjee/oneAPI_dreamTeam/blob/main/oneAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Video -> Audio

# %%
# !pip install moviepy
# !pip install pydub

# %%
import moviepy.editor as mp
from pydub import AudioSegment

video_path = '/content/Sadhguru on the Lost Concept of Heaven.mp4'
video_clip = mp.VideoFileClip(video_path)
audio_clip = video_clip.audio
audio_output_path = '/content/drive/My Drive/audio_extracted/audio_output.mp3'
audio_clip.write_audiofile(audio_output_path)
# Out:
# MoviePy - Writing audio in /content/drive/My Drive/audio_extracted/audio_output.mp3
# MoviePy - Done.

# %% [markdown]
# #Audio -> Text

# %%
 # !pip install git+https://github.com/openai/whisper.git
 # !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-g1rbm6u5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-g1rbm6u5
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.0 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802826 sha256=fdc36151a0e9b674ae69d4bcbd07fab2abb452cdccff7f6fc89708b16090a980
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aiwt7tgd/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# ...

# %%
# !whisper "output1.mp3" --model medium.en
# Out:
# [00:00.000 --> 00:08.080]  Bangalore, India. Two-trimester MSC. AI and milliliter. Research project document.
# [00:08.080 --> 00:13.680]  Department of Computer Science. Optimizing road traffic management through.
# [00:13.680 --> 00:22.800]  Automated video annotation with computer vision. By. Swastik Banerjee. 2348566.
# [00:22.800 --> 00:28.480]  Under the guidance of Dr. Gobi R. January 2024.

# %% [markdown]
# #Text Summarization

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
ARTICLE = """
Virat Kohli, often referred to as the "GOAT" (Greatest of All Time) by many cricket enthusiasts and experts, has earned this title through his exceptional skills, consistency, and impact on the game. Let's delve into the reasons why Kohli is considered one of the greatest cricketers of all time:

### 1. Unparalleled Consistency:
   - Kohli's consistency in all formats of the game is remarkable. Whether it's Test cricket, One Day Internationals (ODIs), or Twenty20 Internationals (T20Is), he has consistently performed at an exceptionally high level.
   - His batting average across formats speaks volumes about his consistency. In ODIs, he averages over 59, in Tests, it's above 52, and in T20Is, it's around 52 (as of 2022).
   - Kohli has been the linchpin of the Indian batting lineup for over a decade. His ability to perform in all conditions, against all opponents, and in different situations is unparalleled.

### 2. Master of Chases:
   - Kohli has earned a reputation as the ultimate chase-master. His ability to finish matches for India, especially in limited-overs cricket, is second to none.
   - When chasing, Kohli averages an astonishing 68.35 in ODIs, which is the highest ever in the history of the format (as of 2022).
   - He has played numerous memorable innings while chasing down targets, often under intense pressure, showcasing his mental strength and composure.

### 3. Incredible Conversion Rate:
   - Kohli is known for converting his starts into big scores. His knack for turning fifties into hundreds is legendary.
   - As of 2022, Kohli has scored a staggering 70 international centuries, with 27 in Tests and 43 in ODIs. This conversion rate is among the best in the history of the game.
   - His hunger for big scores and his ability to dominate bowling attacks for extended periods make him a nightmare for any opposition.

### 4. Adaptability and Versatility:
   - Kohli has the ability to adapt his game to different formats and conditions seamlessly. Whether it's the seaming tracks of England, the bouncy pitches of Australia, or the spinning tracks of India, he finds a way to succeed.
   - His technique is solid, allowing him to excel in both traditional Test cricket as well as the more aggressive limited-overs formats.
   - In T20 cricket, Kohli has shown his versatility by adjusting his game according to the demands of the format, be it anchoring the innings or unleashing his aggressive strokes.

### 5. Captaincy and Leadership:
   - While his captaincy record might not be as illustrious as some others, Kohli's leadership qualities are unquestionable.
   - Under his captaincy, India achieved historic Test series wins in Australia and South Africa.
   - His aggressive and passionate approach on the field has inspired his teammates to raise their game and perform at their best.

### 6. Fitness and Work Ethic:
   - Kohli is a fitness fanatic and has set new standards for fitness in cricket. His dedication to fitness has not only improved his game but has also influenced his teammates and the younger generation of cricketers.
   - His work ethic is exemplary, often spending hours in the nets honing his skills and improving his game.

### 7. Records and Achievements:
   - Kohli holds numerous records across formats, from being the fastest to reach various milestones to the most centuries while chasing.
   - He has won numerous awards, including ICC Cricketer of the Year, ICC Test Player of the Year, and ICC ODI Player of the Year multiple times.

### 8. Impact on the Game:
   - Kohli's influence on the game of cricket goes beyond his personal records. He has inspired a generation of young cricketers with his passion, dedication, and never-say-die attitude.
   - His popularity transcends borders, with fans all over the world admiring his skill and style of play.
   - Kohli has played a significant role in making cricket more accessible and appealing to a wider audience, especially with the rise of the Indian Premier League (IPL) and India's dominance in world cricket.

In conclusion, Virat Kohli's status as the GOAT in cricket is a result of his exceptional skills, unwavering consistency, incredible records, adaptability, leadership qualities, and impact on the game. He has redefined modern-day cricket and will be remembered as one of the greatest to have ever played the sport.
"""

# %%
summarizer(ARTICLE, max_length=200, min_length=100, do_sample=False)
# Out:
# [{'summary_text': ' Virat Kohli is considered the GOAT (Greatest of All Time) by many cricket enthusiasts and experts . He has earned this title through his exceptional skills, consistency, adaptability, leadership qualities, and impact on the game . His ability to perform in all conditions, against all opponents, and in different situations is unparalleled . As of 2022, Kohli has scored a staggering 70 international centuries, with 27 in Tests and 43 in ODIs . He holds numerous records, from being the fastest to reach various milestones to the most centuries while chasing .'}]
